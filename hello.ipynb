# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
def is_leap(year):
    return (year % 4 == 0) and (year % 100 != 0 or year % 400 == 0)

year = int(input())
print(is_leap(year))
# Out:
#  1990
# False
